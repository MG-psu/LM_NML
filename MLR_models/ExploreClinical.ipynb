# %%
import os
import pandas as pd

# %%
clinical_data = pd.read_csv('ClinicalDF1.csv')

# %%
clinical_data.shape
# Out:
# (6802, 17)

# %%
clinical_data.drop(['X','rownames.Clinical.','ProjectID','PackYearsSmoked'],axis=1, inplace=True)

# %%
clinical_data.head()
# Out:
#                                DiseaseType CancerType     SampleType Gender  \
# 0  TransitionalCellPapillomasAndCarcinomas    Bladder  Primary Tumor   male
# 1  TransitionalCellPapillomasAndCarcinomas    Bladder  Primary Tumor   male
# 2  TransitionalCellPapillomasAndCarcinomas    Bladder  Primary Tumor   male
# 3  TransitionalCellPapillomasAndCarcinomas    Bladder  Primary Tumor   male
# 4  TransitionalCellPapillomasAndCarcinomas    Bladder  Primary Tumor   male
#
#    YearOfBirth   Race  DaysToBirth VitalStatus  DaysToDeath  \
# 0       1935.0  white     -27730.0       alive          NaN
# 1       1935.0  white     -28106.0        dead        248.0
# 2       1940.0  white     -26546.0        dead        332.0
# 3       1957.0  white     -20424.0       alive          NaN
# 4       1933.0  white     -25317.0       alive          NaN
#
#                 Ethnicity             PrimaryDiagnosis TumorStage  \
# 0  not hispanic or latino  Transitional cell carcinoma        iii
# ...

# %%
clinical_data.describe(include='all')
# Out:
#                        DiseaseType CancerType     SampleType Gender  \
# count                         6802       6802           6802   6774
# unique                          21         10              6      2
# top     AdenomasAndAdenocarcinomas     Breast  Primary Tumor   male
# freq                          2963       1485           5519   3589
# mean                           NaN        NaN            NaN    NaN
# std                            NaN        NaN            NaN    NaN
# min                            NaN        NaN            NaN    NaN
# 25%                            NaN        NaN            NaN    NaN
# 50%                            NaN        NaN            NaN    NaN
# 75%                            NaN        NaN            NaN    NaN
# max                            NaN        NaN            NaN    NaN
#
#         YearOfBirth   Race   DaysToBirth VitalStatus   DaysToDeath  \
# count   6518.000000   5901   6561.000000        6773   1876.000000
# ...

# %%
clinical_data.CancerType.value_counts()
# Out:
# Breast           1485
# Kidney           1448
# Brain             759
# Colon             675
# ProstateGland     660
# Bladder           488
# Skin              474
# Stomach           460
# Pancreas          188
# Testis            165
# Name: CancerType, dtype: int64

# %%
#!pip install missingno

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(clinical_data)

# %%
msno.bar(clinical_data)

# %%
msno.heatmap(clinical_data)

# %%
msno.dendrogram(clinical_data)
# The dendrogram uses a hierarchical clustering algorithm (courtesy of scipy) to bin variables
# against one another by their nullity correlation (measured in terms of binary distance). 
# At each step of the tree the variables are split up based on which combination minimizes 
# the distance of the remaining clusters. The more monotone the set of variables, the closer 
# their total distance is to zero, and the closer their average distance (the y-axis) is to zero.

# %%
#!pip install pandas-profiling

# %% [markdown]
# ### Using Pandas-Profiling

# %%
from pandas_profiling import ProfileReport

# %%
# profile=ProfileReport(clinical_data, title="Exploring Clinical Dataset",explorative=True,
# dataset={"description":"This profiling report was generated as a part of Thesis report"},
#         correlations={"pearson":{"calculate":True}, 
#                                      "spearman":{"calculate":False},
#                                      "kendall":{"calculate":False},
#                                      "phi_k":{"calculate":False}
#                                      })

# %%
#3 variables
dataframe=clinical_data[['Morphology','AgeAtDiagnosis','Gender','CancerType']]

# %%
dataframe.sample(10)
# Out:
#      Morphology  AgeAtDiagnosis  Gender     CancerType
# 3829     8500/3         17689.0  female         Breast
# 393      8120/3         23116.0  female        Bladder
# 1896     9401/3         11509.0    male          Brain
# 5607     8140/3         21748.0    male  ProstateGland
# 5639     8140/3         24030.0    male  ProstateGland
# 6098     8144/3         20941.0    male        Stomach
# 382      8120/3         32872.0    male        Bladder
# 3643     8500/3         18942.0  female         Breast
# 5071     8310/3         26060.0    male         Kidney
# 2732     8520/3         32872.0  female         Breast

# %%
profile=ProfileReport(dataframe, title="Exploring Clinical Dataset",explorative=True,
dataset={"description":"This profiling report was generated as a part of Thesis report"})

# %% [markdown]
# ### It analyses all the variables as pairs and highlights any highly correlating variables using
# Pearson, Spearman, Kendal and Phik measures.

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-06-30 03:58:38.410292&quot;&gt;&lt;title&gt;Exploring Clinical Dataset&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file('ClinicalDataReportJun_29.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
