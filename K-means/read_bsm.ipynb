# %%
import pandas as pd

# %%
bsm= pd.read_csv('/Users/madhuri/Desktop/MasterThesis/Part1/bsm_2k_random.csv')

# %%
bsm.head()
# Out:
#                                 cid  217398_x_at  1007_s_at  121_at  \
# 0  BSM_E-TABM-90-RAW-CEL-1559882198      14.9210     6.4805  8.1883
# 1  BSM_E-TABM-90-RAW-CEL-1559882206      14.9427     6.6415  8.7040
# 2  BSM_E-TABM-90-RAW-CEL-1559882222      14.9440     6.6642  8.3699
# 3  BSM_E-TABM-90-RAW-CEL-1559882238      14.9481     7.9483  9.0812
# 4  BSM_E-TABM-90-RAW-CEL-1559882254      14.9335     7.3172  8.8104
#
#    200045_at  200053_at  200071_at  200078_s_at  200083_at  200617_at  ...  \
# 0    10.1831     8.5187    11.1252      10.0020    10.0832     8.8516  ...
# 1    10.9209     9.8998     9.5091      11.4438    10.0322     8.6753  ...
# 2    11.3780    10.1662     9.1081      11.5052    10.2779     9.6829  ...
# 3    11.0657    10.3749     9.6479      11.4184    10.7670    10.0884  ...
# 4    10.5564     9.6438     9.6520      10.5210    10.4148     9.0415  ...
#
#    221308_at  221478_at  221539_at  221562_s_at  222103_at  34408_at  \
# ...
